# %%
# !cp /Users/ynaito/github/ecell/ecell3-ipython/extensions/ecell3.py /Users/ynaito/.ipython/extensions/
#%install_ext https://raw.githubusercontent.com/naito/ecell3-ipython/master/extensions/ecell3.py
# %load_ext ecell3

# %%
# %ls /Users/ynaito/github/ecell/ecell3-ipython/extensions/
# Out:
# ecell3.py  tests/

# %%
# %gui qt

# %%
# %loadModel()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-93d12db39533> in <module>()
# ----> 1 get_ipython().magic(u'loadModel ()')
#
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2203         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2204         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2205         return self.run_line_magic(magic_name, magic_arg_s)
#    2206
#    2207     #-------------------------------------------------------------------------
#
# /usr/local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2124                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2125             with self.builtin_trap:
# -> 2126                 result = fn(*args,**kwargs)
#    2127             return result
#    2128
#
# /Users/ynaito/.ipython/extensions/ecell3.py in loadModel(line)
#      96     def loadModel( line ):
#      97         model_file = model_chooser()
# ---> 98         loadModel( model_file )
#      99         print '{} is loaded.'.format( model_file )
#     100
#
# /Users/ynaito/.ipython/extensions/ecell3.py in loadModel(line)
#
# /usr/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     224     # but it's overkill for just that one bit of state.
#     225     def magic_deco(arg):
# --> 226         call = lambda f, *a, **k: f(*a, **k)
#     227
#     228         # Find get_ipython() in the caller's namespace
#
# /Users/ynaito/.ipython/extensions/ecell3.py in loadModel(line)
#      96     def loadModel( line ):
#      97         model_file = model_chooser()
# ---> 98         loadModel( model_file )
#      99         print '{} is loaded.'.format( model_file )
#     100
#
# /Users/ynaito/.ipython/extensions/ecell3.py in loadModel(line)
#
# /usr/local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     224     # but it's overkill for just that one bit of state.
#     225     def magic_deco(arg):
# --> 226         call = lambda f, *a, **k: f(*a, **k)
#     227
#     228         # Find get_ipython() in the caller's namespace
#
# /Users/ynaito/.ipython/extensions/ecell3.py in loadModel(line)
#      95     @register_line_magic
#      96     def loadModel( line ):
# ---> 97         model_file = model_chooser()
#      98         loadModel( model_file )
#      99         print '{} is loaded.'.format( model_file )
#
# /Users/ynaito/.ipython/extensions/ecell3.py in model_chooser(dir)
#      64         "Choose a model file...",                 # QString caption
#      65         dir,                                      # QString directory
# ---> 66         filter = "Model files (*.em *.eml)" )     # QString filter
#      67
#      68     # QFileDialog.getOpenFileName(QWidget parent=None, QString caption=QString(), QString directory=QString(), QString filter=QString(), QString selectedFilter=None, QFileDialog.Options options=0)
#
# KeyboardInterrupt:

# %%
#%matplotlib inline
#import matplotlib.pyplot as plt

# %%
try:
    from PySide import QtCore, QtGui
except ImportError:
    from PyQt4 import QtCore, QtGui

def gui_fname(dir=None):
    """Select a file via a dialog and returns the file name.
    """
    if dir is None: dir ='./'
    fname = QtGui.QFileDialog.getOpenFileName(None, "Choose a model file...", 
            dir, filter = "Model files (*.em *.eml)")
    return fname

# %%
# %gui qt
file_name = gui_fname()
#%matplotlib inline

# %%
#loadModel("Tyson1991.eml")
loadModel( str( file_name ) )

# %%
M = createEntityStub('Variable:/cell:M')
M['Value']
# Out:
# 0.0

# %% [markdown]
# https://plot.ly/python/streaming-tutorial/

# %%
# (*) Import plotly package
import plotly

# Check plolty version (if not latest, please upgrade)
print plotly.__version__
# Out:
# 1.4.4

# %%
# (*) To communicate with Plotly's server, sign in with credentials file
import plotly.plotly as py  

# (*) Useful Python/Plotly tools
import plotly.tools as tls   

# (*) Graph objects to piece together plots
from plotly.graph_objs import *

import numpy as np  # (*) numpy for math functions and arrays

# %%
tls.set_credentials_file(stream_ids=[
    "lqwi4mbiem",
    "jr0n932yqt",
    "j13fz35n6u",
    "ixim9zy821"
])

# %%
stream_ids = tls.get_credentials_file()['stream_ids']

# %%
plot_interval = 0.1
trigger_interval = 50

# Get stream id from stream id list 
#stream_id = stream_ids[1]

# Make instance of stream id object 
stream = Stream(
    token=stream_ids[1],  # (!) link stream id to 'token' key
    maxpoints = int( trigger_interval )     # (!) keep a max of 80 pts on screen
)

# %%
# Initialize trace of streaming plot by embedding the unique stream_id
trace1 = Scatter(
    x=[],
    y=[],
    mode='lines+marke',
    stream=stream         # (!) embed stream id, 1 per trace
)

data = Data([trace1])

# %%
# Add title to layout object
layout = Layout(title='Tracer')

# Make a figure object
fig = Figure(data=data, layout=layout)

# (@) Send fig to Plotly, initialize streaming plot, open new tab
#unique_url = py.plot(fig, filename='Tracer141116')

# %%
tracer = py.Stream( stream_ids[1] )
tracer.open()
#tracer.force_clean()
tracer.write(dict( x = [ getCurrentTime() ], y = [ M['Value'] ] ))
#tracer.write(dict( x = getCurrentTime(), y = M['Value'] ))

# %%
tls.embed('ynaito','1')

# %%
# (*) Import module keep track and format current time
import time   


t = getCurrentTime()

#time.sleep(5) 

t_end = getCurrentTime() + trigger_interval

while t < t_end:
    while t >= getNextEvent()[0]:
        step()
        tracer.write(dict( x = t, y = M['Value'] ))
    t += plot_interval

# %%
tracer.close()

# %%
?? loadModel()
